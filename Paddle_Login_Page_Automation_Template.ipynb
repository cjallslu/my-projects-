# %% [markdown]
# # Website login using requests library in Python
# https://www.youtube.com/watch?v=fmf_y8zpOgA&t=1s

# %%
import requests
from bs4 import BeautifulSoup

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.116 Safari/537.36'
}

# %%
login_data = {
    'name': 'alvin.all2@gmail.com',
    'pass': 'Azwel7#',
    'remember_me': 1,
    'form_id': 'user_login',
    'op': 'Log in'
}

# %%
with requests.Session() as s:
    url = "https://mycptc.org/user/login"
    r = s.get(url, headers=headers)
    soup = BeautifulSoup(r.content, 'html5lib')
    login_data['form_build_id'] = soup.find('input', attrs={'name': 'form_build_id'})['value']
    
    r = s.post(url, data=login_data, headers=headers)
    
    r = 
    print(r.content)
# Out:
# b'<!DOCTYPE html>\n<html lang="en" dir="ltr" prefix="fb: http://www.facebook.com/2008/fbml content: http://purl.org/rss/1.0/modules/content/ dc: http://purl.org/dc/terms/ foaf: http://xmlns.com/foaf/0.1/ og: http://ogp.me/ns# rdfs: http://www.w3.org/2000/01/rdf-schema# sioc: http://rdfs.org/sioc/ns# sioct: http://rdfs.org/sioc/types# skos: http://www.w3.org/2004/02/skos/core# xsd: http://www.w3.org/2001/XMLSchema#">\n<head>\n  <link rel="profile" href="http://www.w3.org/1999/xhtml/vocab" />\n  <meta name="viewport" content="width=device-width, initial-scale=1.0">\n  <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />\n<link rel="shortcut icon" href="https://mycptc.org/sites/all/themes/mycptc/favicon.ico" type="image/vnd.microsoft.icon" />\n<meta name="Generator" content="Drupal 7 (http://drupal.org)" />\n  <title>myCPTC -  Alvin All | MYCPTC</title>\n  <link type="text/css" rel="stylesheet" href="https://mycptc.org/sites/default/files/css/css_lQaZfjVpwP_oGNqdtWCSpJT1EMqXdMiU84ekLLxQnc4.css" media="all" />\n<link type="text/css" rel="stylesheet" href="https://mycptc.org/sites/default/files/css/css_tuqeOBz1ozigHOvScJR2wasCmXBizZ9rfd58u6_20EE.css" media="all" />\n<link type="text/css" rel="stylesheet" href="https://mycptc.org/sites/default/files/css/css_3t2qOZVYs3NQVbcRzkr7PIpf-iL9D6yRh0R4VvBVArc.css" media="all" />\n<link type="text/css" rel="stylesheet" href="https://mycptc.org/sites/default/files/css/css_pgXxCi843UzhPKidAMDhxYxWajKba6J8xr0871uBCuI.css" media="all" />\n<link type="text/css" rel="stylesheet" href="https://cdn.jsdelivr.net/npm/bootstrap@3.4.0/dist/css/bootstrap.min.css" media="all" />\n<link type="text/css" rel="stylesheet" href="https://cdn.jsdelivr.net/npm/@unicorn-fail/drupal-bootstrap-styles@0.0.2/dist/3.3.1/7.x-3.x/drupal-bootstrap.min.css" media="all" />\n<link type="text/css" rel="stylesheet" href="https://mycptc.org/sites/default/files/css/css_Re2PElTr3LOKe0avKTP3Az8mjpwHY7d1xCu-marfV5E.css" media="all" />\n<link type="text/css" rel="stylesheet" href="https://mycptc.org/sites/default/files/css_injector/css_injector_1.css?q6rxfk" media="all" />\n<link type="text/css" rel="stylesheet" href="https://mycptc.org/sites/default/files/css_injector/css_injector_6.css?q6rxfk" media="all" />\n<link type="text/css" rel="stylesheet" href="https://mycptc.org/sites/default/files/css_injector/css_injector_7.css?q6rxfk" media="all" />\n<link type="text/css" rel="stylesheet" href="https://mycptc.org/sites/default/files/css_injector/css_injector_8.css?q6rxfk" media="all" />\n<link type="text/css" rel="stylesheet" href="https://mycptc.org/sites/default/files/css_injector/css_injector_10.css?q6rxfk" media="all" />\n<link type="text/css" rel="stylesheet" href="https://mycptc.org/sites/default/files/css_injector/css_injector_11.css?q6rxfk" media="all" />\n  <!-- HTML5 element support for IE6-8 -->\n  <!--[if lt IE 9]>\n    <script src="https://cdn.jsdelivr.net/html5shiv/3.7.3/html5shiv-printshiv.min.js"></script>\n  <![endif]-->\n  <script src="https://mycptc.org/sites/default/files/js/js_Ik4I8wEq8uU6d57STTv4kkWxCUSXmlOuMJG0pIxbF74.js"></script>\n<script src="https://mycptc.org/sites/default/files/js/js_MN4GIHRczZUE0sWjeK2FI-mF5oC11OInGMdNuMv1TZY.js"></script>\n<script src="https://cdn.jsdelivr.net/npm/bootstrap@3.4.0/dist/js/bootstrap.min.js"></script>\n<script src="https://mycptc.org/sites/default/files/js/js_93Lg_da56pHOd6pcQO4_OfpvIl6T0G-TPb4R2L-4loI.js"></script>\n<script src="https://mycptc.org/sites/default/files/js/js_fjooXJfY1zo7RvsWbBXJQy-C8BRhIWFC7n1QMCfFLMI.js"></script>\n<script src="https://mycptc.org/sites/default/files/js/js_0CGhw2sgw1hIxarShb93uVy8PI0ZtNi6DENFIzInBXU.js"></script>\n<script src="https://mycptc.org/sites/default/files/js/js_Pwl1FHkXQayg1gEBdaN8qUZoAQBfcMONHbkSLESsfx0.js"></script>\n<script>jQuery.extend(Drupal.settings, {"basePath":"\\/","pathPrefix":"","ajaxPageState":{"theme":"mycptc","theme_token":"vNc-exeCJJJ2tSK-MxTGLmTmU7bX1MHF81z7wgWXbWY","jquery_version":"2.1","js":{"sit ...
